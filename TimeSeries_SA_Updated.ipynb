# %%
import os
import pandas as pd
import numpy as np
import scipy
import statsmodels
import sklearn
import datetime
import calendar
from datetime import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from pandasql import sqldf
# %matplotlib inline
import math
import collections
from operator import itemgetter
from collections import OrderedDict
from matplotlib.pyplot import show
from pandas import DataFrame
import seaborn as sns
# Out:
# /Users/chanduboss/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
os.chdir("/Users/chanduboss/Desktop/SUITEAMERICA")
os.getcwd()
# Out:
# '/Users/chanduboss/Desktop/SUITEAMERICA'

# %%
df = pd.read_csv("OrdersData_Timeseries.csv")
df.head()
# Out:
#    Order# MoveInDate MoveOutDate  DailyRent SuiteSizeCode  Status  ZoneCode  \
# 0  285536   14/09/15    28/10/15      254.0           1X1  TERMED       8.0
# 1  289693   16/10/15    14/11/15      250.0           1X1  TERMED       8.0
# 2  354867   25/02/18    26/03/18        NaN           NaN  CANCEL       NaN
# 3  355682   19/02/18    02/03/18      197.0           1X1  TERMED       7.0
# 4  322147   17/12/16    28/02/17      148.0           1X1  TERMED      46.0
#
#             City  State    GuestFirstName Master#                 ComplexName  \
# 0  SAN FRANCISCO  US-CA   Matthew Richard  283368         AVALON HAYES VALLEY
# 1  SAN FRANCISCO  US-CA  Orion Richardson  119226  AVALON MISSION BAY PHASE I
# 2            NaN    NaN          RQ5C71AF     NaN                         NaN
# 3      SAN MATEO  US-CA  Thomas Spanswick  335345     PARK PLACE AT SAN MATEO
# 4      HILLSBORO  US-OR    Michael Ulrich  301739              206 APARTMENTS
#
#   BookedDate StatusChanged  Unnamed: 14
# 0   14/08/15           NaN          NaN
# 1   29/09/15           NaN          NaN
# 2   31/01/18           NaN          NaN
# 3   09/02/18           NaN          NaN
# 4   17/11/16           NaN          NaN

# %%
df.shape
# Out:
# (46850, 15)

# %%
df.describe(include='all')
# Out:
#                Order#  MoveInDate MoveOutDate     DailyRent SuiteSizeCode  \
# count    46850.000000       46777       43974  41806.000000         35213
# unique            NaN        1546        1524           NaN            38
# top               NaN  2018-04-01  2018-06-30           NaN           1X1
# freq              NaN         296         194           NaN         21828
# mean    323875.540406         NaN         NaN    286.298409           NaN
# std      31611.280139         NaN         NaN    421.372716           NaN
# min       5012.000000         NaN         NaN      0.000000           NaN
# 25%     298285.250000         NaN         NaN    150.000000           NaN
# 50%     334230.500000         NaN         NaN    192.000000           NaN
# 75%     350816.750000         NaN         NaN    236.000000           NaN
# max     363867.000000         NaN         NaN   3000.000000           NaN
#
#         Status      ZoneCode       City  State GuestFirstName Master#  \
# count    46850  34560.000000      35180  35180          45186   35213
# unique       6           NaN        409     46          34874    6324
# top     TERMED           NaN  CUPERTINO  US-CA            TBD  259056
# freq     29349           NaN       6376  24298            717    2657
# mean       NaN     14.090943        NaN    NaN            NaN     NaN
# std        NaN     15.692640        NaN    NaN            NaN     NaN
# min        NaN      1.000000        NaN    NaN            NaN     NaN
# 25%        NaN      5.000000        NaN    NaN            NaN     NaN
# 50%        NaN      7.000000        NaN    NaN            NaN     NaN
# 75%        NaN     13.000000        NaN    NaN            NaN     NaN
# max        NaN     77.000000        NaN    NaN            NaN     NaN
#
#        ComplexName  BookedDate StatusChanged  Unnamed: 14
# count        35207       46804          1306          0.0
# unique        1660        1304            38          NaN
# top          APPLE  2018-02-20    2018-05-04          NaN
# freq          2709         159            68          NaN
# mean           NaN         NaN           NaN          NaN
# std            NaN         NaN           NaN          NaN
# min            NaN         NaN           NaN          NaN
# 25%            NaN         NaN           NaN          NaN
# 50%            NaN         NaN           NaN          NaN
# 75%            NaN         NaN           NaN          NaN
# max            NaN         NaN           NaN          NaN

# %%
df.dtypes
# Out:
# Order#              int64
# MoveInDate         object
# MoveOutDate        object
# DailyRent         float64
# SuiteSizeCode      object
# Status             object
# ZoneCode          float64
# City               object
# State              object
# GuestFirstName     object
# Master#            object
# ComplexName        object
# BookedDate         object
# StatusChanged      object
# Unnamed: 14       float64
# dtype: object

# %%
df['MoveInDate'] = pd.to_datetime(df['MoveInDate'],format='%Y-%m-%d %H:%M')
df["MoveOutDate"] = pd.to_datetime(df['MoveOutDate'],format='%Y-%m-%d %H:%M')
df['MoveInDate_week'] = df['MoveInDate'].dt.weekday_name
df["MoveOutDay_Week"] = df["MoveOutDate"].dt.weekday_name
df['Move_In_Month']= df.MoveInDate.dt.month
df["Move_Out_Month"] = df.MoveOutDate.dt.month
df['Move_In_year']=df.MoveInDate.dt.year
df['Move_Out_Year'] = df.MoveOutDate.dt.year

# %%
#df["stay"] = (df["MoveOutDate"] - df["MoveInDate"]).dt.days

# %%
del df['Unnamed: 14']
del df['ComplexName']
del df['GuestFirstName']

# %%
df.dtypes.count
# Out:
# <bound method Series.count of Order#                      int64
# MoveInDate         datetime64[ns]
# MoveOutDate        datetime64[ns]
# DailyRent                 float64
# SuiteSizeCode              object
# Status                     object
# ZoneCode                  float64
# City                       object
# State                      object
# Master#                    object
# BookedDate                 object
# StatusChanged              object
# MoveInDate_week            object
# MoveOutDay_Week            object
# Move_In_Month             float64
# Move_Out_Month            float64
# Move_In_year              float64
# Move_Out_Year             float64
# dtype: object>

# %%
df.shape
# Out:
# (46850, 18)

# %%
df.head(15)
# Out:
#     Order# MoveInDate MoveOutDate  DailyRent SuiteSizeCode  Status  ZoneCode  \
# 0   285536 2015-09-14  2015-10-28      254.0           1X1  TERMED       8.0
# 1   289693 2015-10-16  2015-11-14      250.0           1X1  TERMED       8.0
# 2   354867 2018-02-25  2018-03-26        NaN           NaN  CANCEL       NaN
# 3   355682 2018-02-19  2018-03-02      197.0           1X1  TERMED       7.0
# 4   322147 2016-12-17  2017-02-28      148.0           1X1  TERMED      46.0
# 5   305710 2016-05-29  2016-06-27      219.0           1X1  TERMED       5.0
# 6   348736 2017-11-26         NaT        NaN           NaN  CANCEL       NaN
# 7   362371 2018-05-01  2018-05-21      202.0           1X1  ACTIVE       5.0
# 8   361210 2018-05-09  2018-06-07        0.0           NaN  CANCEL       NaN
# 9   326135 2017-03-21  2017-04-15      236.0           2X2  TERMED      42.0
# 10  350055 2017-11-30  2017-12-20      139.0           1X1  TERMED       3.0
# 11  345405 2017-10-28  2017-11-26      214.0           1X1  CANCEL       5.0
# 12  270557 2015-05-06  2015-05-13      195.0           NaN  TERMED       NaN
# 13  314291 2016-07-22  2016-07-22     2025.0           1X1  TERMED       5.0
# 14  263566 2015-01-15  2015-02-09      138.0           1X1  TERMED      10.0
#
#              City  State Master#  BookedDate StatusChanged MoveInDate_week  \
# 0   SAN FRANCISCO  US-CA  283368  2015-08-14           NaN          Monday
# 1   SAN FRANCISCO  US-CA  119226  2015-09-29           NaN          Friday
# 2             NaN    NaN     NaN  2018-01-31           NaN          Sunday
# 3       SAN MATEO  US-CA  335345  2018-02-09           NaN          Monday
# 4       HILLSBORO  US-OR  301739  2016-11-17           NaN        Saturday
# 5       CUPERTINO  US-CA  238110  2016-04-26           NaN          Sunday
# 6             NaN    NaN     NaN  2017-11-07           NaN          Sunday
# 7       SUNNYVALE  US-CA  278650  2018-04-30    2018-04-30         Tuesday
# 8             NaN    NaN     NaN  2018-04-13           NaN       Wednesday
# 9      WASHINGTON  US-DC  326751  2017-02-02           NaN         Tuesday
# 10        FREMONT  US-CA  349005  2017-11-27           NaN        Thursday
# 11      SUNNYVALE  US-CA  330347  2017-09-25           NaN        Saturday
# 12            NaN    NaN     NaN  2015-04-15           NaN       Wednesday
# 13      CUPERTINO  US-CA  259056  2016-07-22           NaN          Friday
# 14      ARLINGTON  US-VA  233823  2015-01-14           NaN        Thursday
#
#    MoveOutDay_Week  Move_In_Month  Move_Out_Month  Move_In_year  Move_Out_Year
# 0        Wednesday            9.0            10.0        2015.0         2015.0
# 1         Saturday           10.0            11.0        2015.0         2015.0
# 2           Monday            2.0             3.0        2018.0         2018.0
# 3           Friday            2.0             3.0        2018.0         2018.0
# 4          Tuesday           12.0             2.0        2016.0         2017.0
# 5           Monday            5.0             6.0        2016.0         2016.0
# 6              NaN           11.0             NaN        2017.0            NaN
# 7           Monday            5.0             5.0        2018.0         2018.0
# 8         Thursday            5.0             6.0        2018.0         2018.0
# 9         Saturday            3.0             4.0        2017.0         2017.0
# 10       Wednesday           11.0            12.0        2017.0         2017.0
# 11          Sunday           10.0            11.0        2017.0         2017.0
# 12       Wednesday            5.0             5.0        2015.0         2015.0
# 13          Friday            7.0             7.0        2016.0         2016.0
# 14          Monday            1.0             2.0        2015.0         2015.0

# %%
df['sum']=df.isnull().sum(axis=1)

# %%
df.describe()
# Out:
#               Order#     DailyRent      ZoneCode  Move_In_Month  \
# count   46850.000000  41806.000000  34560.000000   46777.000000
# mean   323875.540406    286.298409     14.090943       6.030977
# std     31611.280139    421.372716     15.692640       3.374918
# min      5012.000000      0.000000      1.000000       1.000000
# 25%    298285.250000    150.000000      5.000000       3.000000
# 50%    334230.500000    192.000000      7.000000       6.000000
# 75%    350816.750000    236.000000     13.000000       9.000000
# max    363867.000000   3000.000000     77.000000      12.000000
#
#        Move_Out_Month  Move_In_year  Move_Out_Year           sum
# count    43974.000000  46777.000000   43974.000000  46850.000000
# mean         6.423273   2016.597409    2016.746691      2.589840
# std          3.286883      1.281791       3.146523      2.725725
# min          1.000000   1994.000000    2015.000000      0.000000
# 25%          4.000000   2016.000000    2016.000000      1.000000
# 50%          6.000000   2017.000000    2017.000000      1.000000
# 75%          9.000000   2018.000000    2018.000000      6.000000
# max         12.000000   2106.000000    2099.000000     16.000000

# %%
df.isnull().sum()
# Out:
# Order#                 0
# MoveInDate            73
# MoveOutDate         2876
# DailyRent           5044
# SuiteSizeCode      11637
# Status                 0
# ZoneCode           12290
# City               11670
# State              11670
# Master#            11637
# BookedDate            46
# StatusChanged      45544
# MoveInDate_week       73
# MoveOutDay_Week     2876
# Move_In_Month         73
# Move_Out_Month      2876
# Move_In_year          73
# Move_Out_Year       2876
# sum                    0
# dtype: int64

# %%
d = ["CANCEL","QUOTE","VOID"]
new_data = df[~df["Status"].isin(d)]

# %%
new_data.shape
# Out:
# (31171, 19)

# %%
new_data.head()
# Out:
#    Order# MoveInDate MoveOutDate  DailyRent SuiteSizeCode  Status  ZoneCode  \
# 0  285536 2015-09-14  2015-10-28      254.0           1X1  TERMED       8.0
# 1  289693 2015-10-16  2015-11-14      250.0           1X1  TERMED       8.0
# 3  355682 2018-02-19  2018-03-02      197.0           1X1  TERMED       7.0
# 4  322147 2016-12-17  2017-02-28      148.0           1X1  TERMED      46.0
# 5  305710 2016-05-29  2016-06-27      219.0           1X1  TERMED       5.0
#
#             City  State Master#  BookedDate StatusChanged MoveInDate_week  \
# 0  SAN FRANCISCO  US-CA  283368  2015-08-14           NaN          Monday
# 1  SAN FRANCISCO  US-CA  119226  2015-09-29           NaN          Friday
# 3      SAN MATEO  US-CA  335345  2018-02-09           NaN          Monday
# 4      HILLSBORO  US-OR  301739  2016-11-17           NaN        Saturday
# 5      CUPERTINO  US-CA  238110  2016-04-26           NaN          Sunday
#
#   MoveOutDay_Week  Move_In_Month  Move_Out_Month  Move_In_year  Move_Out_Year  \
# 0       Wednesday            9.0            10.0        2015.0         2015.0
# 1        Saturday           10.0            11.0        2015.0         2015.0
# 3          Friday            2.0             3.0        2018.0         2018.0
# 4         Tuesday           12.0             2.0        2016.0         2017.0
# 5          Monday            5.0             6.0        2016.0         2016.0
#
#    sum
# 0    1
# 1    1
# 3    1
# 4    1
# 5    1

# %%
df_MI = pd.DataFrame(data= new_data.MoveInDate, index=None)
df_MI = df_MI.rename(columns={'MoveInDate': 'Date'})

# %%
df_MI['Date'] = pd.to_datetime(df_MI['Date'],format= '%d-%m-%Y')

# %%
df_MI['Date'] = pd.to_datetime(df_MI['Date'])

# %%
df_MI.shape
# Out:
# (31171, 1)

# %%
df_MI.head()
# Out:
#         Date
# 0 2015-09-14
# 1 2015-10-16
# 3 2018-02-19
# 4 2016-12-17
# 5 2016-05-29

# %%
df_MI['year']= df_MI['Date'].dt.year
df_MI
df_MI['Month']= df_MI['Date'].dt.month
df_MI['Weak']= df_MI['Date'].dt.weekday_name
df_MI['Count']= 1

# %%
df_MI.head(20)
# Out:
#          Date  year  Month       Weak  Count
# 0  2015-09-14  2015      9     Monday      1
# 1  2015-10-16  2015     10     Friday      1
# 3  2018-02-19  2018      2     Monday      1
# 4  2016-12-17  2016     12   Saturday      1
# 5  2016-05-29  2016      5     Sunday      1
# 7  2018-05-01  2018      5    Tuesday      1
# 9  2017-03-21  2017      3    Tuesday      1
# 10 2017-11-30  2017     11   Thursday      1
# 12 2015-05-06  2015      5  Wednesday      1
# 13 2016-07-22  2016      7     Friday      1
# 14 2015-01-15  2015      1   Thursday      1
# 16 2016-10-01  2016     10   Saturday      1
# 17 2016-08-04  2016      8   Thursday      1
# 18 2016-01-25  2016      1     Monday      1
# 21 2017-01-08  2017      1     Sunday      1
# 23 2015-06-13  2015      6   Saturday      1
# 27 2015-09-26  2015      9   Saturday      1
# 28 2016-05-16  2016      5     Monday      1
# 30 2015-08-16  2015      8     Sunday      1
# 31 2017-02-12  2017      2     Sunday      1

# %%
df_MI = df_MI[df_MI["year"] > 2013]
df_MI = df_MI[df_MI["year"] < 2019]

# %%
df_MI.head()
# Out:
#         Date  year  Month      Weak  Count
# 0 2015-09-14  2015      9    Monday      1
# 1 2015-10-16  2015     10    Friday      1
# 3 2018-02-19  2018      2    Monday      1
# 4 2016-12-17  2016     12  Saturday      1
# 5 2016-05-29  2016      5    Sunday      1

# %%
min(df_MI['Date'])
# Out:
# Timestamp('2014-01-09 00:00:00')

# %%
max(df_MI.Date)
# Out:
# Timestamp('2018-11-01 00:00:00')

# %%
df_MI.dtypes
# Out:
# Date     datetime64[ns]
# year              int64
# Month             int64
# Weak             object
# Count             int64
# dtype: object

# %%
df_MI.Date= pd.to_datetime(df_MI.Date, format="%Y%m%d").sort_values()

# %%
sortdate= pd.DataFrame(df_MI.Date.sort_values())

# %%
sortdate["COUNT"] =1
sortdate.head()
# Out:
#             Date  COUNT
# 12870 2014-01-09      1
# 27005 2014-01-11      1
# 40660 2014-01-23      1
# 22077 2014-02-03      1
# 35148 2014-02-12      1

# %%
df_MI.to_csv('sortfile.csv')

# %%
df_final = pd.read_csv("sortfile.csv", st)
df_final.head()
df_final.tail()
df_final= df_final.sort_values(by='Date')

df_final['Count']= df_final.groupby('Date')['Date'].transform('count')

# %%
del df_final['Unnamed: 0']

# %%
print(df_final)
# Out:
#              Date  year  Month       Weak  Count
# 8552   2014-01-09  2014      1   Thursday      1
# 17976  2014-01-11  2014      1   Saturday      1
# 26982  2014-01-23  2014      1   Thursday      1
# 14717  2014-02-03  2014      2     Monday      1
# 23395  2014-02-12  2014      2  Wednesday      1
# 25248  2014-02-13  2014      2   Thursday      2
# 27643  2014-02-13  2014      2   Thursday      2
# 18165  2014-02-18  2014      2    Tuesday      1
# 24896  2014-02-22  2014      2   Saturday      1
# 11063  2014-03-03  2014      3     Monday      2
# 16940  2014-03-03  2014      3     Monday      2
# 30024  2014-03-04  2014      3    Tuesday      1
# 20013  2014-03-07  2014      3     Friday      1
# 15413  2014-03-17  2014      3     Monday      1
# 2212   2014-03-18  2014      3    Tuesday      1
# 16207  2014-03-19  2014      3  Wednesday      1
# 5330   2014-03-22  2014      3   Saturday      1
# 12950  2014-03-26  2014      3  Wednesday      1
# 11038  2014-03-29  2014      3   Saturday      1
# 26536  2014-04-15  2014      4    Tuesday      1
# 12706  2014-04-23  2014      4  Wednesday      2
# 23834  2014-04-23  2014      4  Wednesday      2
# 23512  2014-05-01  2014      5   Thursday      1
# 17493  2014-05-03  2014      5   Saturday      1
# 5386   2014-05-09  2014      5     Friday      3
# 10882  2014-05-09  2014      5     Friday      3
# 5642   2014-05-09  2014      5     Friday      3
# 26780  2014-05-14  2014      5  Wednesday      1
# 5363   2014-05-17  2014      5   Saturday      1
# 8694   2014-05-22  2014      5   Thursday      4
# ...           ...   ...    ...        ...    ...
# 10457  2018-06-16  2018      6   Saturday      4
# 24847  2018-06-16  2018      6   Saturday      4
# 1374   2018-06-16  2018      6   Saturday      4
# 28523  2018-06-16  2018      6   Saturday      4
# 22930  2018-06-17  2018      6     Sunday      4
# 4024   2018-06-17  2018      6     Sunday      4
# 20201  2018-06-17  2018      6     Sunday      4
# 3470   2018-06-17  2018      6     Sunday      4
# 13918  2018-06-18  2018      6     Monday      1
# 20368  2018-06-22  2018      6     Friday      2
# 12690  2018-06-22  2018      6     Friday      2
# 18235  2018-06-23  2018      6   Saturday      1
# 17550  2018-06-24  2018      6     Sunday      1
# 28358  2018-06-28  2018      6   Thursday      1
# 16811  2018-06-30  2018      6   Saturday      1
# 17123  2018-07-01  2018      7     Sunday      5
# 19810  2018-07-01  2018      7     Sunday      5
# 30978  2018-07-01  2018      7     Sunday      5
# 15415  2018-07-01  2018      7     Sunday      5
# 5256   2018-07-01  2018      7     Sunday      5
# 4890   2018-07-02  2018      7     Monday      1
# 25204  2018-07-06  2018      7     Friday      1
# 22287  2018-07-08  2018      7     Sunday      1
# 30561  2018-07-12  2018      7   Thursday      1
# 293    2018-07-16  2018      7     Monday      1
# 30111  2018-07-27  2018      7     Friday      1
# 7706   2018-09-01  2018      9   Saturday      2
# 14528  2018-09-01  2018      9   Saturday      2
# 16453  2018-10-01  2018     10     Monday      1
# 15080  2018-11-01  2018     11   Thursday      1
#
# [31138 rows x 5 columns]

# %%
df_final1= df_final.groupby(['Date','year','Month'], as_index=False)['Count'].sum()
df_final1
# Out:
#             Date  year  Month  Count
# 0     2014-01-09  2014      1      1
# 1     2014-01-11  2014      1      1
# 2     2014-01-23  2014      1      1
# 3     2014-02-03  2014      2      1
# 4     2014-02-12  2014      2      1
# 5     2014-02-13  2014      2      4
# 6     2014-02-18  2014      2      1
# 7     2014-02-22  2014      2      1
# 8     2014-03-03  2014      3      4
# 9     2014-03-04  2014      3      1
# 10    2014-03-07  2014      3      1
# 11    2014-03-17  2014      3      1
# 12    2014-03-18  2014      3      1
# 13    2014-03-19  2014      3      1
# 14    2014-03-22  2014      3      1
# 15    2014-03-26  2014      3      1
# 16    2014-03-29  2014      3      1
# 17    2014-04-15  2014      4      1
# 18    2014-04-23  2014      4      4
# 19    2014-05-01  2014      5      1
# 20    2014-05-03  2014      5      1
# 21    2014-05-09  2014      5      9
# 22    2014-05-14  2014      5      1
# 23    2014-05-17  2014      5      1
# 24    2014-05-22  2014      5     16
# 25    2014-05-24  2014      5      1
# 26    2014-06-01  2014      6      1
# 27    2014-06-03  2014      6      4
# 28    2014-06-05  2014      6      9
# 29    2014-06-14  2014      6      1
# ...          ...   ...    ...    ...
# 1431  2018-06-04  2018      6    121
# 1432  2018-06-05  2018      6     36
# 1433  2018-06-06  2018      6     49
# 1434  2018-06-07  2018      6     36
# 1435  2018-06-08  2018      6    100
# 1436  2018-06-09  2018      6     36
# 1437  2018-06-10  2018      6     64
# 1438  2018-06-11  2018      6     16
# 1439  2018-06-12  2018      6      1
# 1440  2018-06-13  2018      6      4
# 1441  2018-06-14  2018      6      4
# 1442  2018-06-15  2018      6     36
# 1443  2018-06-16  2018      6     16
# 1444  2018-06-17  2018      6     16
# 1445  2018-06-18  2018      6      1
# 1446  2018-06-22  2018      6      4
# 1447  2018-06-23  2018      6      1
# 1448  2018-06-24  2018      6      1
# 1449  2018-06-28  2018      6      1
# 1450  2018-06-30  2018      6      1
# 1451  2018-07-01  2018      7     25
# 1452  2018-07-02  2018      7      1
# 1453  2018-07-06  2018      7      1
# 1454  2018-07-08  2018      7      1
# 1455  2018-07-12  2018      7      1
# 1456  2018-07-16  2018      7      1
# 1457  2018-07-27  2018      7      1
# 1458  2018-09-01  2018      9      4
# 1459  2018-10-01  2018     10      1
# 1460  2018-11-01  2018     11      1
#
# [1461 rows x 4 columns]

# %%
date1= min(df_final1['Date'])
date2= max(df_final1['Date'])

# %%
mydates = pd.date_range(date1, date2).tolist()
#dates= pd.DataFrame(mydates)

# %%
mydates = [str(m).split()[0] for m in mydates]
missing = list(set(mydates)-set(list(df_final1['Date'])))
print(missing)
type(missing)
# Out:
# ['2018-08-10', '2018-09-11', '2014-09-24', '2018-07-04', '2014-01-31', '2014-09-17', '2018-10-22', '2014-03-27', '2014-09-19', '2014-06-15', '2018-09-24', '2014-01-10', '2014-04-10', '2014-07-05', '2014-01-18', '2018-10-03', '2018-10-25', '2014-09-30', '2018-08-02', '2014-02-21', '2014-09-14', '2018-07-20', '2018-09-26', '2014-01-21', '2014-07-12', '2018-10-16', '2014-01-17', '2018-10-14', '2018-08-18', '2018-07-11', '2014-07-21', '2014-04-30', '2014-02-28', '2018-10-29', '2018-07-15', '2014-05-15', '2018-08-16', '2018-08-21', '2014-04-18', '2014-05-06', '2014-09-01', '2014-03-02', '2014-05-31', '2014-05-11', '2014-04-14', '2014-05-30', '2014-02-17', '2018-08-08', '2014-04-08', '2014-03-20', '2014-07-02', '2014-04-25', '2018-08-13', '2018-07-22', '2018-09-05', '2018-10-24', '2014-06-26', '2014-01-15', '2014-08-02', '2018-08-23', '2018-10-31', '2014-05-27', '2014-05-19', '2018-06-29', '2014-05-08', '2014-04-07', '2018-07-29', '2014-06-04', '2018-09-20', '2018-09-18', '2014-09-07', '2014-03-21', '2014-07-27', '2018-09-25', '2014-05-07', '2018-07-28', '2018-10-28', '2018-10-26', '2018-08-06', '2018-08-07', '2014-06-08', '2018-09-06', '2014-02-20', '2014-04-06', '2018-07-25', '2014-04-24', '2018-10-02', '2014-02-07', '2014-07-14', '2018-08-04', '2014-05-12', '2014-04-21', '2018-08-22', '2014-06-07', '2018-08-17', '2014-09-25', '2018-07-19', '2014-04-16', '2014-06-02', '2014-03-24', '2018-10-23', '2014-04-27', '2014-01-24', '2018-07-21', '2018-10-04', '2018-06-20', '2018-09-19', '2018-07-07', '2014-01-27', '2014-03-28', '2018-08-14', '2018-08-29', '2018-08-28', '2014-06-23', '2018-07-26', '2018-08-11', '2018-07-23', '2014-03-30', '2014-01-28', '2014-08-13', '2014-08-10', '2018-09-27', '2018-10-06', '2018-09-16', '2014-02-09', '2014-04-01', '2014-02-16', '2014-04-04', '2014-06-12', '2014-02-02', '2014-01-25', '2014-05-21', '2014-03-08', '2018-10-30', '2018-09-21', '2014-04-02', '2018-10-12', '2014-09-22', '2018-06-27', '2014-05-04', '2014-07-19', '2018-08-19', '2018-09-23', '2014-03-12', '2018-09-10', '2014-08-22', '2014-02-01', '2014-09-08', '2018-09-04', '2014-07-10', '2014-04-28', '2014-03-14', '2014-07-07', '2014-02-19', '2018-07-31', '2014-05-25', '2014-04-13', '2018-10-09', '2014-02-15', '2014-08-24', '2014-02-26', '2014-07-28', '2018-07-18', '2014-06-09', '2018-08-27', '2018-10-21', '2018-10-17', '2014-04-12', '2018-09-15', '2014-07-11', '2018-07-13', '2018-09-02', '2018-09-22', '2018-08-26', '2014-04-26', '2014-07-18', '2014-03-23', '2014-09-18', '2014-06-06', '2014-08-06', '2014-03-11', '2014-06-11', '2018-10-20', '2014-03-10', '2014-03-31', '2014-01-29', '2014-01-22', '2018-06-25', '2014-06-24', '2014-02-08', '2014-05-18', '2014-03-13', '2018-09-13', '2014-04-22', '2018-06-19', '2014-06-25', '2014-09-16', '2014-02-27', '2018-10-07', '2014-04-11', '2018-08-31', '2014-05-26', '2018-08-01', '2018-09-17', '2014-07-16', '2014-06-16', '2014-08-12', '2018-10-05', '2014-05-05', '2018-08-03', '2018-07-14', '2018-10-11', '2018-07-17', '2014-06-17', '2018-10-10', '2014-04-20', '2018-07-10', '2014-03-15', '2018-06-21', '2014-04-19', '2014-05-10', '2018-10-18', '2014-03-25', '2018-08-20', '2014-05-16', '2014-01-30', '2018-09-29', '2014-01-13', '2018-07-24', '2014-01-20', '2014-09-21', '2014-04-29', '2014-07-04', '2014-03-09', '2018-08-15', '2014-05-20', '2014-04-17', '2018-08-05', '2014-03-05', '2018-10-08', '2014-06-13', '2014-10-19', '2018-09-08', '2018-10-15', '2014-01-12', '2018-10-19', '2014-02-25', '2014-01-16', '2014-07-31', '2014-02-10', '2018-09-28', '2014-06-10', '2014-02-04', '2016-12-25', '2018-06-26', '2018-08-09', '2014-02-24', '2018-07-09', '2018-09-03', '2014-04-09', '2014-02-23', '2014-04-03', '2018-08-30', '2018-07-05', '2018-09-07', '2014-05-13', '2014-03-06', '2018-10-13', '2014-03-01', '2018-09-09', '2018-07-30', '2014-03-16', '2018-08-25', '2014-02-06', '2014-05-23', '2018-09-12', '2014-09-12', '2014-05-28', '2017-12-24', '2014-02-14', '2014-01-26', '2014-05-29', '2014-07-25', '2018-09-30', '2018-10-27', '2014-05- ...
# list

# %%
df_final2= df_final1.append(missing,ignore_index=False)
# Out:
# /Users/chanduboss/anaconda/lib/python3.6/site-packages/pandas/core/indexes/api.py:77: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)

# %%
print(df_final2)
# Out:
#            Date    year  Month  Count           0
# 0    2014-01-09  2014.0    1.0    1.0         NaN
# 1    2014-01-11  2014.0    1.0    1.0         NaN
# 2    2014-01-23  2014.0    1.0    1.0         NaN
# 3    2014-02-03  2014.0    2.0    1.0         NaN
# 4    2014-02-12  2014.0    2.0    1.0         NaN
# 5    2014-02-13  2014.0    2.0    4.0         NaN
# 6    2014-02-18  2014.0    2.0    1.0         NaN
# 7    2014-02-22  2014.0    2.0    1.0         NaN
# 8    2014-03-03  2014.0    3.0    4.0         NaN
# 9    2014-03-04  2014.0    3.0    1.0         NaN
# 10   2014-03-07  2014.0    3.0    1.0         NaN
# 11   2014-03-17  2014.0    3.0    1.0         NaN
# 12   2014-03-18  2014.0    3.0    1.0         NaN
# 13   2014-03-19  2014.0    3.0    1.0         NaN
# 14   2014-03-22  2014.0    3.0    1.0         NaN
# 15   2014-03-26  2014.0    3.0    1.0         NaN
# 16   2014-03-29  2014.0    3.0    1.0         NaN
# 17   2014-04-15  2014.0    4.0    1.0         NaN
# 18   2014-04-23  2014.0    4.0    4.0         NaN
# 19   2014-05-01  2014.0    5.0    1.0         NaN
# 20   2014-05-03  2014.0    5.0    1.0         NaN
# 21   2014-05-09  2014.0    5.0    9.0         NaN
# 22   2014-05-14  2014.0    5.0    1.0         NaN
# 23   2014-05-17  2014.0    5.0    1.0         NaN
# 24   2014-05-22  2014.0    5.0   16.0         NaN
# 25   2014-05-24  2014.0    5.0    1.0         NaN
# 26   2014-06-01  2014.0    6.0    1.0         NaN
# 27   2014-06-03  2014.0    6.0    4.0         NaN
# 28   2014-06-05  2014.0    6.0    9.0         NaN
# 29   2014-06-14  2014.0    6.0    1.0         NaN
# ..          ...     ...    ...    ...         ...
# 267         NaN     NaN    NaN    NaN  2018-10-13
# 268         NaN     NaN    NaN    NaN  2014-03-01
# 269         NaN     NaN    NaN    NaN  2018-09-09
# 270         NaN     NaN    NaN    NaN  2018-07-30
# 271         NaN     NaN    NaN    NaN  2014-03-16
# 272         NaN     NaN    NaN    NaN  2018-08-25
# 273         NaN     NaN    NaN    NaN  2014-02-06
# 274         NaN     NaN    NaN    NaN  2014-05-23
# 275         NaN     NaN    NaN    NaN  2018-09-12
# 276         NaN     NaN    NaN    NaN  2014-09-12
# 277         NaN     NaN    NaN    NaN  2014-05-28
# 278         NaN     NaN    NaN    NaN  2017-12-24
# 279         NaN     NaN    NaN    NaN  2014-02-14
# 280         NaN     NaN    NaN    NaN  2014-01-26
# 281         NaN     NaN    NaN    NaN  2014-05-29
# 282         NaN     NaN    NaN    NaN  2014-07-25
# 283         NaN     NaN    NaN    NaN  2018-09-30
# 284         NaN     NaN    NaN    NaN  2018-10-27
# 285         NaN     NaN    NaN    NaN  2014-05-02
# 286         NaN     NaN    NaN    NaN  2014-02-11
# 287         NaN     NaN    NaN    NaN  2014-02-05
# 288         NaN     NaN    NaN    NaN  2014-01-14
# 289         NaN     NaN    NaN    NaN  2018-08-24
# 290         NaN     NaN    NaN    NaN  2018-08-12
# 291         NaN     NaN    NaN    NaN  2018-07-03
# 292         NaN     NaN    NaN    NaN  2014-07-23
# 293         NaN     NaN    NaN    NaN  2018-09-14
# 294         NaN     NaN    NaN    NaN  2014-04-05
# 295         NaN     NaN    NaN    NaN  2014-08-25
# 296         NaN     NaN    NaN    NaN  2014-01-19
#
# [1758 rows x 5 columns]

# %%
names=  ['Date']
dates.columns= names

# %%
dates1= list(df_final1['Date'])
type(dates1)
# Out:
# list

# %%
df_final.to_csv('FINAL_TS.csv')

# %%
TS = pd.read_csv("FINAL_TS.csv")
TS.head(2)
# Out:
#    Unnamed: 0        Date  year  Month      Weak  Count
# 0        8552  2014-01-09  2014      1  Thursday      1
# 1       17976  2014-01-11  2014      1  Saturday      1

# %%
#parse_dates=["Date"], index_col="Date")

# %%
del TS['Unnamed: 0']

# %%
TS.head(30)
# Out:
#           Date  year  Month       Weak  Count
# 0   2014-01-09  2014      1   Thursday      1
# 1   2014-01-11  2014      1   Saturday      1
# 2   2014-01-23  2014      1   Thursday      1
# 3   2014-02-03  2014      2     Monday      1
# 4   2014-02-12  2014      2  Wednesday      1
# 5   2014-02-13  2014      2   Thursday      2
# 6   2014-02-13  2014      2   Thursday      2
# 7   2014-02-18  2014      2    Tuesday      1
# 8   2014-02-22  2014      2   Saturday      1
# 9   2014-03-03  2014      3     Monday      2
# 10  2014-03-03  2014      3     Monday      2
# 11  2014-03-04  2014      3    Tuesday      1
# 12  2014-03-07  2014      3     Friday      1
# 13  2014-03-17  2014      3     Monday      1
# 14  2014-03-18  2014      3    Tuesday      1
# 15  2014-03-19  2014      3  Wednesday      1
# 16  2014-03-22  2014      3   Saturday      1
# 17  2014-03-26  2014      3  Wednesday      1
# 18  2014-03-29  2014      3   Saturday      1
# 19  2014-04-15  2014      4    Tuesday      1
# 20  2014-04-23  2014      4  Wednesday      2
# 21  2014-04-23  2014      4  Wednesday      2
# 22  2014-05-01  2014      5   Thursday      1
# 23  2014-05-03  2014      5   Saturday      1
# 24  2014-05-09  2014      5     Friday      3
# 25  2014-05-09  2014      5     Friday      3
# 26  2014-05-09  2014      5     Friday      3
# 27  2014-05-14  2014      5  Wednesday      1
# 28  2014-05-17  2014      5   Saturday      1
# 29  2014-05-22  2014      5   Thursday      4

# %%
TS.shape
# Out:
# (31138, 5)

# %%
#TS['year'].resample('M').mean()

# %%
TS.sort_index(by='Count', ascending=[False])
# Out:
# /Users/chanduboss/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)
#   """Entry point for launching an IPython kernel.
#              Date  year  Month       Weak  Count
# 28315  2018-01-21  2018      1     Sunday    173
# 28180  2018-01-21  2018      1     Sunday    173
# 28172  2018-01-21  2018      1     Sunday    173
# 28173  2018-01-21  2018      1     Sunday    173
# 28174  2018-01-21  2018      1     Sunday    173
# 28175  2018-01-21  2018      1     Sunday    173
# 28176  2018-01-21  2018      1     Sunday    173
# 28177  2018-01-21  2018      1     Sunday    173
# 28178  2018-01-21  2018      1     Sunday    173
# 28179  2018-01-21  2018      1     Sunday    173
# 28181  2018-01-21  2018      1     Sunday    173
# 28170  2018-01-21  2018      1     Sunday    173
# 28182  2018-01-21  2018      1     Sunday    173
# 28184  2018-01-21  2018      1     Sunday    173
# 28185  2018-01-21  2018      1     Sunday    173
# 28186  2018-01-21  2018      1     Sunday    173
# 28187  2018-01-21  2018      1     Sunday    173
# 28188  2018-01-21  2018      1     Sunday    173
# 28189  2018-01-21  2018      1     Sunday    173
# 28190  2018-01-21  2018      1     Sunday    173
# 28171  2018-01-21  2018      1     Sunday    173
# 28169  2018-01-21  2018      1     Sunday    173
# 28192  2018-01-21  2018      1     Sunday    173
# 28242  2018-01-21  2018      1     Sunday    173
# 28339  2018-01-21  2018      1     Sunday    173
# 28249  2018-01-21  2018      1     Sunday    173
# 28248  2018-01-21  2018      1     Sunday    173
# 28247  2018-01-21  2018      1     Sunday    173
# 28246  2018-01-21  2018      1     Sunday    173
# 28245  2018-01-21  2018      1     Sunday    173
# ...           ...   ...    ...        ...    ...
# 174    2014-10-06  2014     10     Monday      1
# 175    2014-10-07  2014     10    Tuesday      1
# 185    2014-10-11  2014     10   Saturday      1
# 186    2014-10-12  2014     10     Sunday      1
# 211    2014-10-21  2014     10    Tuesday      1
# 232    2014-10-27  2014     10     Monday      1
# 237    2014-10-29  2014     10  Wednesday      1
# 278    2014-11-05  2014     11  Wednesday      1
# 317    2014-11-12  2014     11  Wednesday      1
# 351    2014-11-19  2014     11  Wednesday      1
# 1      2014-01-11  2014      1   Saturday      1
# 140    2014-09-10  2014      9  Wednesday      1
# 130    2014-09-03  2014      9  Wednesday      1
# 117    2014-08-27  2014      8  Wednesday      1
# 98     2014-08-08  2014      8     Friday      1
# 92     2014-07-30  2014      7  Wednesday      1
# 93     2014-08-01  2014      8     Friday      1
# 94     2014-08-03  2014      8     Sunday      1
# 95     2014-08-04  2014      8     Monday      1
# 96     2014-08-05  2014      8    Tuesday      1
# 97     2014-08-07  2014      8   Thursday      1
# 99     2014-08-09  2014      8   Saturday      1
# 116    2014-08-26  2014      8    Tuesday      1
# 102    2014-08-14  2014      8   Thursday      1
# 103    2014-08-15  2014      8     Friday      1
# 104    2014-08-16  2014      8   Saturday      1
# 110    2014-08-19  2014      8    Tuesday      1
# 111    2014-08-20  2014      8  Wednesday      1
# 112    2014-08-21  2014      8   Thursday      1
# 31137  2018-11-01  2018     11   Thursday      1
#
# [31138 rows x 5 columns]

# %%
TS.index
# Out:
# DatetimeIndex(['2014-01-09', '2014-01-11', '2014-01-23', '2014-02-03',
#                '2014-02-12', '2014-02-13', '2014-02-13', '2014-02-18',
#                '2014-02-22', '2014-03-03',
#                ...
#                '2018-09-17', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-19', '2018-11-01', '2018-11-06', '2018-11-11',
#                '2018-11-18', '2018-12-15'],
#               dtype='datetime64[ns]', name='Date', length=46739, freq=None)

# %%
print(TS)
# Out:
#               year  Month       Weak  Count
# Date
# 2014-01-09  2014.0    1.0   Thursday      1
# 2014-01-11  2014.0    1.0   Saturday      1
# 2014-01-23  2014.0    1.0   Thursday      1
# 2014-02-03  2014.0    2.0     Monday      1
# 2014-02-12  2014.0    2.0  Wednesday      1
# 2014-02-13  2014.0    2.0   Thursday      2
# 2014-02-13  2014.0    2.0   Thursday      2
# 2014-02-18  2014.0    2.0    Tuesday      1
# 2014-02-22  2014.0    2.0   Saturday      1
# 2014-03-03  2014.0    3.0     Monday      2
# 2014-03-03  2014.0    3.0     Monday      2
# 2014-03-04  2014.0    3.0    Tuesday      1
# 2014-03-07  2014.0    3.0     Friday      1
# 2014-03-17  2014.0    3.0     Monday      1
# 2014-03-18  2014.0    3.0    Tuesday      1
# 2014-03-19  2014.0    3.0  Wednesday      1
# 2014-03-22  2014.0    3.0   Saturday      1
# 2014-03-26  2014.0    3.0  Wednesday      1
# 2014-03-29  2014.0    3.0   Saturday      1
# 2014-04-15  2014.0    4.0    Tuesday      1
# 2014-04-23  2014.0    4.0  Wednesday      2
# 2014-04-23  2014.0    4.0  Wednesday      2
# 2014-05-01  2014.0    5.0   Thursday      1
# 2014-05-03  2014.0    5.0   Saturday      1
# 2014-05-09  2014.0    5.0     Friday      3
# 2014-05-09  2014.0    5.0     Friday      3
# 2014-05-09  2014.0    5.0     Friday      3
# 2014-05-14  2014.0    5.0  Wednesday      1
# 2014-05-17  2014.0    5.0   Saturday      1
# 2014-05-22  2014.0    5.0   Thursday      4
# ...            ...    ...        ...    ...
# 2018-08-18  2018.0    8.0   Saturday      5
# 2018-08-18  2018.0    8.0   Saturday      5
# 2018-08-19  2018.0    8.0     Sunday      1
# 2018-08-24  2018.0    8.0     Friday      1
# 2018-08-29  2018.0    8.0  Wednesday      1
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-01  2018.0    9.0   Saturday      8
# 2018-09-02  2018.0    9.0     Sunday      2
# 2018-09-02  2018.0    9.0     Sunday      2
# 2018-09-04  2018.0    9.0    Tuesday      1
# 2018-09-07  2018.0    9.0     Friday      1
# 2018-09-09  2018.0    9.0     Sunday      1
# 2018-09-13  2018.0    9.0   Thursday      2
# 2018-09-13  2018.0    9.0   Thursday      2
# 2018-09-17  2018.0    9.0     Monday      1
# 2018-10-01  2018.0   10.0     Monday      3
# 2018-10-01  2018.0   10.0     Monday      3
# 2018-10-01  2018.0   10.0     Monday      3
# 2018-10-19  2018.0   10.0     Friday      1
# 2018-11-01  2018.0   11.0   Thursday      1
# 2018-11-06  2018.0   11.0    Tuesday      1
# 2018-11-11  2018.0   11.0     Sunday      1
# 2018-11-18  2018.0   11.0     Sunday      1
# 2018-12-15  2018.0   12.0   Saturday      1
#
# [46739 rows x 4 columns]

# %%
TS.index
# Out:
# DatetimeIndex(['2014-01-09', '2014-01-11', '2014-01-23', '2014-02-03',
#                '2014-02-12', '2014-02-13', '2014-02-13', '2014-02-18',
#                '2014-02-22', '2014-03-03',
#                ...
#                '2018-09-17', '2018-10-01', '2018-10-01', '2018-10-01',
#                '2018-10-19', '2018-11-01', '2018-11-06', '2018-11-11',
#                '2018-11-18', '2018-12-15'],
#               dtype='datetime64[ns]', name='Date', length=46739, freq=None)

# %%
TS.Month.resample('M').mean()
# Out:
# Date
# 2014-01-31     1.0
# 2014-02-28     2.0
# 2014-03-31     3.0
# 2014-04-30     4.0
# 2014-05-31     5.0
# 2014-06-30     6.0
# 2014-07-31     7.0
# 2014-08-31     8.0
# 2014-09-30     9.0
# 2014-10-31    10.0
# 2014-11-30    11.0
# 2014-12-31    12.0
# 2015-01-31     1.0
# 2015-02-28     2.0
# 2015-03-31     3.0
# 2015-04-30     4.0
# 2015-05-31     5.0
# 2015-06-30     6.0
# 2015-07-31     7.0
# 2015-08-31     8.0
# 2015-09-30     9.0
# 2015-10-31    10.0
# 2015-11-30    11.0
# 2015-12-31    12.0
# 2016-01-31     1.0
# 2016-02-29     2.0
# 2016-03-31     3.0
# 2016-04-30     4.0
# 2016-05-31     5.0
# 2016-06-30     6.0
# 2016-07-31     7.0
# 2016-08-31     8.0
# 2016-09-30     9.0
# 2016-10-31    10.0
# 2016-11-30    11.0
# 2016-12-31    12.0
# 2017-01-31     1.0
# 2017-02-28     2.0
# 2017-03-31     3.0
# 2017-04-30     4.0
# 2017-05-31     5.0
# 2017-06-30     6.0
# 2017-07-31     7.0
# 2017-08-31     8.0
# 2017-09-30     9.0
# 2017-10-31    10.0
# 2017-11-30    11.0
# 2017-12-31    12.0
# 2018-01-31     1.0
# 2018-02-28     2.0
# 2018-03-31     3.0
# 2018-04-30     4.0
# 2018-05-31     5.0
# 2018-06-30     6.0
# 2018-07-31     7.0
# 2018-08-31     8.0
# 2018-09-30     9.0
# 2018-10-31    10.0
# 2018-11-30    11.0
# 2018-12-31    12.0
# Freq: M, Name: Month, dtype: float64

# %%
# %matplotlib inline
TS['Month'].plot()
